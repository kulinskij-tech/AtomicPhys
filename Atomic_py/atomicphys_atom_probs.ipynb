# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kulinskij-tech/AtomicPhys/blob/main/Atomic_py/atomicphys_atom_probs.ipynb)

# %% [markdown]
# ## Задачі
# $\newcommand{\ket}[1]{\left.\vert\, #1\, \right \rangle}$
# $\newcommand{\bra}[1]{ \left \langle \, #1\, \right.\vert}$
# $\newcommand{\braket}[2]{ \left \langle \, #1\,\vphantom{#2} \right.\vert \,#2\, \left.\vphantom{#1}\right \rangle}$
# <!--  -->
# <img src="./figs/atphys_probself_at1.png" alt="Image" width="600" height="200">
# <!--  -->

# %% [markdown]
# __Задача__ Оцінити масимальне значення сили яка діє на електрон у моделі атому Томсона.

# %% [markdown]
# <img src="./figs/atphys_probself_at2.png" alt="Image" width="600" height="200">

# %% [markdown]
# <img src="./figs/atphys_probself_at4.png" alt="Image" width="600" height="200">
