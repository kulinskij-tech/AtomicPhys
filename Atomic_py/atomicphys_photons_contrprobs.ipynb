# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kulinskij-tech/AtomicPhys/blob/main/Atomic_py/atomicphys_photons_contrprobs.ipynb)

# %% [markdown]
# # Задачі на квантові властивості світла. Фото- та Комптон- ефект
# $\newcommand{\ket}[1]{\left.\left\vert\, #1\,\right. \right \rangle}$
# $\newcommand{\bra}[1]{\left. \langle \, #1\, \right\vert}$
# $\newcommand{\braket}[2]{\langle \,#1 \vert #2 \, \rangle}$
# $\newcommand{\av}[3]{\left\langle \,#1 \left \vert\, #2 \,\right\vert #3 \,\right \rangle}$

# %% [markdown]
# ### Контрольні задачі:
# <!--  -->
# __Задача:__ Визначить кут виліту вільного електрону та його енергію при Комптон-розсіяння на ньому фотона? (вважати, що до розсіяння електром був у спокої)
# ***
# __Задача:__ Все теж саме що і в [Задачі зі сферою](https://colab.research.google.com/github/kulinskij-tech/AtomicPhys/blob/main/Atomic_py/atomicphys_photons_probs.ipynb#prob_sphere) для випадка гаусівського пучка інтенсивність в перерізі якого описується формулою
# <!--  -->
# $$I(y) = \frac{I_0}{\sigma\,\sqrt{2\pi}}\,e^{-\frac{r^2}{2\,\sigma^2}}$$
# <!--  -->
# Розглянути випадки $\sigma\ll R$ та $\sigma\gg R$.
# ***

# %% [markdown]
# ***
# __Задача__ Використовуючи дані графіка (бажано оцифрувати графік знявши дані з растрової картинки) супутника
# <a href=http://lambda.gsfc.nasa.gov/product/cobe/firas_image.cfm>COBE (1992)</a>, встановіть за формулою Планка температуру реліктового випромінювання Всесвіту.
# ***
# <img src="./figs/fig_plankcobe.png" alt="Image" width="400" height="100">
